# %% [markdown]
# # Unified Anomaly Detection: Training & Evaluation Launcher

# %% [markdown]
# ## 1. Preparation

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')

# Clone the repository code
# !git clone https://github.com/Fabio-Feruglio/Jet-Image-Tagging.git

# Move to the correct folder
# %cd Jet-Image-Tagging/anomaly_detection
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'Jet-Image-Tagging' already exists and is not an empty directory.
# /content/Jet-Image-Tagging/anomaly_detection

# %%
# Install dependencies
# !pip install optuna wandb

# Authenticate on WandB
from google.colab import userdata
import wandb
wandb.login(key=userdata.get('WANDB_API_KEY'))
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.9.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.28.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.5)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.51)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.51)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.13.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.16.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: fabio-feruglio02 (jet--image--tagging) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# TensorBoard loader
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/

# %%
# Copy the dataset from Drive to local storage
# !cp /content/drive/MyDrive/JetTagging/data/jet_images_128.h5 /content/jet_images_128.h5
print("Dataset copied to local storage.")
# Out:
# Dataset copied to local storage.

# %% [markdown]
# ## 2. Autoencoder (AE) Mode

# %%
# Train AE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model ae \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE" \
    --epochs 2 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 5000 \
    --patience 10

# %%
# Evaluate AE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model ae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE/ae_best.pth" \
    --max_samples 5000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/AE/"
# Out:
# /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py:124: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Signal Efficiency ($\epsilon_S$)')
# /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py:125: SyntaxWarning: invalid escape sequence '\e'
#   plt.ylabel('Background Rejection ($1/\epsilon_B$)')
# Device: cuda
# Total Background samples: 347931
# Total Anomaly samples: 532069
# Limiting Background dataset to 5000 samples (stratified)...
# Train set size (only bg): 3500
# Validation set size (only bg): 750
# Test set size (bg + anomalies): 1500
# Loading cached mean and std from dataset_stats.json...
# Loading model weights from: /content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE/ae_best.pth
#
# --- Eval on set: VALIDATION ---
# Evaluating: 100% 12/12 [00:08<00:00,  1.34it/s]
#
# Results VALIDATION:
# Mean Reconstruction Loss: 1.129624
# Skipping ROC curves for VALIDATION (No anomalies).
# Computing PCA and t-SNE for latent space projection (VALIDATION)
#
# --- Eval on set: TEST ---
# Evaluating: 100% 24/24 [00:12<00:00,  1.91it/s]
#
# Results TEST:
# Mean Reconstruction Loss: 1.056836
# Computing PCA and t-SNE for latent space projection (TEST)

# %% [markdown]
# ## 3. Variational Autoencoder (VAE) Mode

# %%
# Train VAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model vae \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/VAE" \
    --epochs 2 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 5000 \
    --patience 10
# Out:
# 2026-07-29 18:29:30.171483: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Selected Device: cuda
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: fabio-feruglio02 (jet--image--tagging) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ setting up run fo5va4wf (0.0s)
# wandb: ⣻ setting up run fo5va4wf (0.0s)
# wandb: ⣽ setting up run fo5va4wf (0.0s)
# wandb: ⣾ setting up run fo5va4wf (0.0s)
# wandb: ⣷ setting up run fo5va4wf (0.0s)
# wandb: ⣯ setting up run fo5va4wf (0.5s)
# wandb: ⣟ setting up run fo5va4wf (0.5s)
# wandb: ⡿ setting up run fo5va4wf (0.5s)
# wandb: ⢿ setting up run fo5va4wf (0.5s)
# wandb: ⣻ setting up run fo5va4wf (1.0s)
# wandb: ⣽ setting up run fo5va4wf (1.0s)
# wandb: ⣾ setting up run fo5va4wf (1.0s)
# wandb: ⣷ setting up run fo5va4wf (1.0s)
# wandb: ⣯ setting up run fo5va4wf (1.0s)
# wandb: ⣟ setting up run fo5va4wf (1.5s)
# wandb: ⡿ setting up run fo5va4wf (1.5s)
# wandb: ⢿ setting up run fo5va4wf (1.5s)
# wandb: ⣻ setting up run fo5va4wf (1.5s)
# wandb: ⣽ setting up run fo5va4wf (1.5s)
# wandb: ⣾ setting up run fo5va4wf (2.0s)
# wandb: ⣷ setting up run fo5va4wf (2.0s)
# wandb: ⣯ setting up run fo5va4wf (2.0s)
# wandb: ⣟ setting up run fo5va4wf (2.0s)
# wandb: ⡿ setting up run fo5va4wf (2.0s)
# wandb: ⢿ setting up run fo5va4wf (2.5s)
# wandb: ⣻ setting up run fo5va4wf (2.5s)
# wandb: ⣽ setting up run fo5va4wf (2.5s)
# wandb: ⣾ setting up run fo5va4wf (2.5s)
# wandb: ⣷ setting up run fo5va4wf (2.5s)
# wandb: ⣯ setting up run fo5va4wf (3.0s)
# wandb: ⣟ setting up run fo5va4wf (3.0s)
# wandb: ⡿ setting up run fo5va4wf (3.0s)
# wandb: ⢿ setting up run fo5va4wf (3.0s)
# wandb: ⣻ setting up run fo5va4wf (3.0s)
# wandb: ⣽ setting up run fo5va4wf (3.5s)
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/Jet-Image-Tagging/anomaly_detection/wandb/run-20260729_182938-fo5va4wf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train_vae_lr0.0001
# wandb: ⭐️ View project at https://wandb.ai/jet--image--tagging/jet-tagging-anomaly-detection-vae-attempt
# wandb: 🚀 View run at https://wandb.ai/jet--image--tagging/jet-tagging-anomaly-detection-vae-attempt/runs/fo5va4wf
# Total Background samples: 347931
# Total Anomaly samples: 532069
# Limiting Background dataset to 5000 samples (stratified)...
# Train set size (only bg): 3500
# Validation set size (only bg): 750
# Test set size (bg + anomalies): 1500
# Loading cached mean and std from dataset_stats.json...
# Train loss: 0.8782: 100% 55/55 [00:32<00:00,  1.69it/s]
# Val loss: 0.8982: 100% 12/12 [00:05<00:00,  2.01it/s]
# Validation Loss: 0.9493
# EPOCH 1/2 - Train Loss: 1.1699
# EPOCH 1/2 - Validation Loss: 0.9493
# Train loss: 0.9479:  69% 38/55 [00:26<00:08,  2.09it/s]

# %%
# Evaluate VAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model vae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/VAE/vae_best.pth" \
    --max_samples 5000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/VAE/"

# %% [markdown]
# ## 4. Sparse Autoencoder (SAE) Mode

# %%
# Train SAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model sae \
    --l1_lambda 0.0001 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SAE" \
    --epochs 2 \
    --latent_space_dim 16 \
    --batch_size 256 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 5000 \
    --patience 10

# %%
# Evaluate SAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model sae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SAE/sae_best.pth" \
    --max_samples 5000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/SAE/"
