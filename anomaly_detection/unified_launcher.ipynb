# %% [markdown]
# # Unified Anomaly Detection: Training & Evaluation Launcher

# %% [markdown]
# ## 1. Preparation

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')

# Clone the repository code
# !git clone https://github.com/Fabio-Feruglio/Jet-Image-Tagging.git

# Move to the correct folder
# %cd Jet-Image-Tagging/anomaly_detection

# %%
# Install dependencies
# !pip install optuna wandb

# Authenticate on WandB
from google.colab import userdata
import wandb
wandb.login(key=userdata.get('WANDB_API_KEY'))

# %%
# TensorBoard loader
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/

# %%
# Copy the dataset from Drive to local storage
# !cp /content/drive/MyDrive/JetTagging/data/jet_images_128.h5 /content/jet_images_128.h5
print("Dataset copied to local storage.")

# %% [markdown]
# ## 2. Autoencoder (AE) Mode

# %%
# Train AE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model ae \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE" \
    --epochs 30 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 30000 \
    --patience 10

# %%
# Evaluate AE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model ae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE/ae_best.pth" \
    --max_samples 30000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/AE/"

# %% [markdown]
# ## 3. Variational Autoencoder (VAE) Mode

# %%
# Train VAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model vae \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/VAE" \
    --epochs 30 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 30000 \
    --patience 10

# %%
# Evaluate VAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model vae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/VAE/vae_best.pth" \
    --max_samples 30000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/VAE/"

# %% [markdown]
# ## 4. Sparse Autoencoder (SAE) Mode

# %%
# Train SAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model sae \
    --l1_lambda 0.0001 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SAE" \
    --epochs 30 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 30000 \
    --patience 10

# %%
# Evaluate SAE
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model sae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SAE/sae_best.pth" \
    --max_samples 30000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/SAE/"

# %% [markdown]
# ## 5. AdaGrad AutoEncoder (AGAE)

# %%
# Train AE with AdaGrad
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model ae \
    --optimizer adagrad \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE_AdaGrad" \
    --epochs 30 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 30000 \
    --patience 10

# %%
# Evaluate AE with AdaGrad
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model ae \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/AE_AdaGrad/ae_best.pth" \
    --max_samples 30000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/AE_AdaGrad/"

# %% [markdown]
# ## 6. Supervised Contrastive AutoEncoder (SCAE) Mode

# %%
# Train SupCon Model
# !python /content/Jet-Image-Tagging/anomaly_detection/src/train_unified.py \
    --model hybrid \
    --optimizer adam \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SCAE" \
    --epochs 30 \
    --latent_space_dim 16 \
    --lambda_weight 0.1 \
    --batch_size 64 \
    --lr 0.0001 \
    --bg_classes 0 1 \
    --img_size 128 \
    --weight_decay 0.0001 \
    --max_samples 30000 \
    --patience 10

# %%
# Evaluate Hybrid SupCon Model
# !python /content/Jet-Image-Tagging/anomaly_detection/src/evaluate_unified.py \
    --model hybrid \
    --model_path "/content/drive/MyDrive/JetTagging/anomaly_detection/checkpoints/SCAE/hybrid_best.pth" \
    --max_samples 30000 \
    --latent_space_dim 16 \
    --batch_size 64 \
    --img_size 128 \
    --bg_classes 0 1 \
    --data_path "/content/jet_images_128.h5" \
    --save_dir "/content/drive/MyDrive/JetTagging/anomaly_detection/results/SCAE/"
