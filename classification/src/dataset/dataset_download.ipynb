# %%
# !pip install jetnet

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/Fabio-Feruglio/Jet-Image-Tagging.git

# Move to the correct folder
# %cd Jet-Image-Tagging/classification/src/dataset

# %%
# Execute the train.py file in /src
# !python src/dataset_preprocessing.py --output_file "/content/drive/MyDrive/JetTagging/data/jet_images_299.h5" --batch_size 1000 --data_dir "/content/drive/MyDrive/JetTagging/data" --im_size 299
